# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import axes
import matplotlib.dates as mdates
from matplotlib import dates
from matplotlib import ticker
from scipy.optimize import curve_fit
from scipy import stats
import seaborn as sns
from ThymeBoost import ThymeBoost as tb
import random
from datetime import datetime, timedelta
import math
from tqdm import tqdm
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
DIR = "data/"
PATH_CHANNELS_DST = DIR + "df_channels_en.tsv"
PATH_TIME_SERIES_DST = DIR + "df_timeseries_en.tsv"
PATH_COMMENTS_AUTHOR_DST = DIR + "num_comments_authors.tsv.gz"
PATH_COMMENTS_DST = DIR + "num_comments.tsv.gz"
PATH_METADATA_DST = DIR + "yt_metadata_en.jsonl.gz"
PATH_METADATA_HELPER = DIR + "yt_metadata_helper.feather"

# %%
timeseries = pd.read_csv(PATH_TIME_SERIES_DST, sep = '\t')
timeseries['datetime']= pd.to_datetime(timeseries['datetime'])
timeseries['delta_views'] = timeseries['delta_views'].round(decimals = 3)
timeseries['subs'] = timeseries['subs'].round(decimals = 3)
timeseries['delta_subs'] = timeseries['delta_subs'].round(decimals = 3)
timeseries.head()
# Out:
#                     channel            category   datetime         views  \
# 0  UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation 2017-07-03  2.024946e+05
# 1  UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation 2017-07-10  3.940857e+05
# 2  UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation 2017-07-17  8.353938e+05
# 3  UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation 2017-07-24  1.104577e+06
# 4  UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation 2017-07-31  1.284406e+06
#
#    delta_views      subs  delta_subs  videos  delta_videos  activity
# 0        0.000   650.222       0.000       5             0         3
# 1   191591.111  1046.000     395.778       6             1         1
# 2   441308.083  1501.500     455.500       6             0         1
# 3   269183.250  1750.000     248.500       6             0         0
# 4   179828.600  2008.300     258.300       6             0         0

# %%
timeseries_filtered = timeseries[timeseries.datetime > pd.to_datetime("2017-1-1")]
print("We know have {} datapoints".format(len(timeseries_filtered)))
# Out:
# We know have 16732615 datapoints

# %%
channel_timeseries = pd.pivot_table(timeseries_filtered, values='delta_views', 
                                index=['datetime'], 
                                columns=['channel'])
print("Without uniformization, we have {} rows.".format(len(channel_timeseries)))
channel_timeseries.head()
# Out:
# Without uniformization, we have 288 rows.
# channel              UC--24Q3_ZQeFmgJE-Um5QZQ  UC--2EbuIuBOGgGqPiJxi3rg  \
# datetime
# 2017-01-01 23:00:00                  2731.406                 27667.057
# 2017-01-02 00:00:00                       NaN                       NaN
# 2017-01-08 23:00:00                  4190.594                 32073.417
# 2017-01-09 00:00:00                       NaN                       NaN
# 2017-01-15 23:00:00                  8811.448                 60385.818
#
# channel              UC--3c8RqSfAqYBdDjIG3UNA  UC--3ozenTzry39-xMqAPQlw  \
# datetime
# 2017-01-01 23:00:00                       NaN                 78790.542
# 2017-01-02 00:00:00                       NaN                       NaN
# 2017-01-08 23:00:00                       NaN                 83433.521
# 2017-01-09 00:00:00                       NaN                       NaN
# 2017-01-15 23:00:00                       NaN                176154.271
#
# channel              UC--6E6EpybocdaNlPhvK_9A  UC--70ql_IxJmhmqXqrkJrWQ  \
# datetime
# 2017-01-01 23:00:00                 45266.219                 58624.651
# 2017-01-02 00:00:00                       NaN                       NaN
# 2017-01-08 23:00:00                 58383.031                261201.391
# 2017-01-09 00:00:00                       NaN                       NaN
# 2017-01-15 23:00:00                105656.375                436874.953
#
# channel              UC--7oyGW0N7fMf164-ZXljQ  UC--94OGFAzYDOJb0eXgMjew  \
# datetime
# 2017-01-01 23:00:00                       NaN                       NaN
# 2017-01-02 00:00:00                       NaN                       NaN
# 2017-01-08 23:00:00                       NaN                       NaN
# 2017-01-09 00:00:00                       NaN                       NaN
# 2017-01-15 23:00:00                       NaN                       NaN
#
# channel              UC--BMyA2X4a9PGAo3lTuopg  UC--EwQJeJ6SKlJdswehQH4g  ...  \
# datetime                                                                 ...
# 2017-01-01 23:00:00                230144.542                  3141.141  ...
# 2017-01-02 00:00:00                       NaN                       NaN  ...
# 2017-01-08 23:00:00                211393.042                  3132.073  ...
# 2017-01-09 00:00:00                       NaN                       NaN  ...
# 2017-01-15 23:00:00                410550.208                  5420.714  ...
#
# channel              UCzzmGsmy8cBxmqljbVG_e7Q  UCzzoJY_ln_StRVdrRX1_ftg  \
# datetime
# 2017-01-01 23:00:00                  1723.201                  4365.896
# 2017-01-02 00:00:00                       NaN                       NaN
# 2017-01-08 23:00:00                  2196.625                  2537.089
# 2017-01-09 00:00:00                       NaN                       NaN
# 2017-01-15 23:00:00                  4063.500                 11802.484
#
# channel              UCzzqd0yx7h1PuC3KJVqeJgw  UCzzsKg4jPGBL05t2w3HfHBA  \
# datetime
# 2017-01-01 23:00:00                       NaN                 17874.796
# 2017-01-02 00:00:00                   389.792                       NaN
# 2017-01-08 23:00:00                       NaN                 21798.781
# 2017-01-09 00:00:00                   413.875                       NaN
# 2017-01-15 23:00:00                       NaN                 44051.906
#
# channel              UCzzt-UNlRHbEFY3rEpFpuXw  UCzztaOtjmaZoiLvWLagq7bg  \
# datetime
# 2017-01-01 23:00:00                 14840.513                       NaN
# 2017-01-02 00:00:00                       NaN                       NaN
# 2017-01-08 23:00:00                 15995.781                       NaN
# 2017-01-09 00:00:00                       NaN                       NaN
# 2017-01-15 23:00:00                 24833.911                       NaN
#
# channel              UCzzyt9Z70MBX9RQAFVSNlpQ  UCzzzPMh9fZHxc7gxPRB2LHQ  \
# datetime
# 2017-01-01 23:00:00                       NaN                 11938.087
# 2017-01-02 00:00:00                       NaN                       NaN
# 2017-01-08 23:00:00                       NaN                 16928.234
# 2017-01-09 00:00:00                       NaN                       NaN
# 2017-01-15 23:00:00                       NaN                 23935.083
#
# channel              UCzzzUN8yvD2LRAnY-lhzyLQ  UCzzzZ3-icktxbC3j7hkWqRw
# datetime
# 2017-01-01 23:00:00                  8823.580                 57680.059
# 2017-01-02 00:00:00                       NaN                       NaN
# 2017-01-08 23:00:00                 11129.797                 68525.880
# 2017-01-09 00:00:00                       NaN                       NaN
# 2017-01-15 23:00:00                 17847.375                141159.036
#
# [5 rows x 133492 columns]

# %%
# Project the timestamp to the correct day
uniform_datetime = timeseries_filtered.copy(deep=True)
uniform_datetime.datetime = uniform_datetime.datetime - timedelta(hours = 2)
# Drop the time to only keep the day
uniform_datetime.datetime = pd.to_datetime(uniform_datetime.datetime).dt.date
uniform_channel_timeseries = pd.pivot_table(uniform_datetime, values='delta_views', 
                                index=['datetime'], 
                                columns=['channel'])
print("With uniformization, we have {} rows.".format(len(channel_timeseries)))
uniform_channel_timeseries.head()
# Out:
# With uniformization, we have 288 rows.
# channel     UC--24Q3_ZQeFmgJE-Um5QZQ  UC--2EbuIuBOGgGqPiJxi3rg  \
# datetime
# 2017-01-01                  2731.406                 27667.057
# 2017-01-08                  4190.594                 32073.417
# 2017-01-15                  8811.448                 60385.818
# 2017-01-22                  4207.583                 31155.448
# 2017-01-29                     0.000                     0.000
#
# channel     UC--3c8RqSfAqYBdDjIG3UNA  UC--3ozenTzry39-xMqAPQlw  \
# datetime
# 2017-01-01                       NaN                 78790.542
# 2017-01-08                       NaN                 83433.521
# 2017-01-15                       NaN                176154.271
# 2017-01-22                       NaN                170651.932
# 2017-01-29                       NaN                     0.000
#
# channel     UC--6E6EpybocdaNlPhvK_9A  UC--70ql_IxJmhmqXqrkJrWQ  \
# datetime
# 2017-01-01                 45266.219                 58624.651
# 2017-01-08                 58383.031                261201.391
# 2017-01-15                105656.375                436874.953
# 2017-01-22                118148.547                237834.172
# 2017-01-29                     0.000                     0.000
#
# channel     UC--7oyGW0N7fMf164-ZXljQ  UC--94OGFAzYDOJb0eXgMjew  \
# datetime
# 2017-01-01                       NaN                       NaN
# 2017-01-08                       NaN                       NaN
# 2017-01-15                       NaN                       NaN
# 2017-01-22                       NaN                       NaN
# 2017-01-29                       NaN                       NaN
#
# channel     UC--BMyA2X4a9PGAo3lTuopg  UC--EwQJeJ6SKlJdswehQH4g  ...  \
# datetime                                                        ...
# 2017-01-01                230144.542                  3141.141  ...
# 2017-01-08                211393.042                  3132.073  ...
# 2017-01-15                410550.208                  5420.714  ...
# 2017-01-22                351185.609                  4501.188  ...
# 2017-01-29                     0.000                     0.000  ...
#
# channel     UCzzmGsmy8cBxmqljbVG_e7Q  UCzzoJY_ln_StRVdrRX1_ftg  \
# datetime
# 2017-01-01                  1723.201                  4365.896
# 2017-01-08                  2196.625                  2537.089
# 2017-01-15                  4063.500                 11802.484
# 2017-01-22                  1467.172                 18982.250
# 2017-01-29                     0.000                     0.000
#
# channel     UCzzqd0yx7h1PuC3KJVqeJgw  UCzzsKg4jPGBL05t2w3HfHBA  \
# datetime
# 2017-01-01                   389.792                 17874.796
# 2017-01-08                   413.875                 21798.781
# 2017-01-15                  1117.375                 44051.906
# 2017-01-22                     0.000                 40054.531
# 2017-01-29                    97.125                     0.000
#
# channel     UCzzt-UNlRHbEFY3rEpFpuXw  UCzztaOtjmaZoiLvWLagq7bg  \
# datetime
# 2017-01-01                 14840.513                       NaN
# 2017-01-08                 15995.781                       NaN
# 2017-01-15                 24833.911                       NaN
# 2017-01-22                 20701.083                       NaN
# 2017-01-29                     0.000                       NaN
#
# channel     UCzzyt9Z70MBX9RQAFVSNlpQ  UCzzzPMh9fZHxc7gxPRB2LHQ  \
# datetime
# 2017-01-01                       NaN                 11938.087
# 2017-01-08                       NaN                 16928.234
# 2017-01-15                       NaN                 23935.083
# 2017-01-22                       NaN                 28294.255
# 2017-01-29                       NaN                     0.000
#
# channel     UCzzzUN8yvD2LRAnY-lhzyLQ  UCzzzZ3-icktxbC3j7hkWqRw
# datetime
# 2017-01-01                  8823.580                 57680.059
# 2017-01-08                 11129.797                 68525.880
# 2017-01-15                 17847.375                141159.036
# 2017-01-22                  8019.599                 89166.245
# 2017-01-29                  1184.635                     0.000
#
# [5 rows x 133492 columns]

# %%
channel_timeseries = uniform_channel_timeseries.dropna(thresh=len(uniform_channel_timeseries) - 1, axis=1)
channel_timeseries
# Out:
# channel     UC--24Q3_ZQeFmgJE-Um5QZQ  UC--2EbuIuBOGgGqPiJxi3rg  \
# datetime
# 2017-01-01                  2731.406                 27667.057
# 2017-01-08                  4190.594                 32073.417
# 2017-01-15                  8811.448                 60385.818
# 2017-01-22                  4207.583                 31155.448
# 2017-01-29                     0.000                     0.000
# ...                              ...                       ...
# 2019-09-01                 12050.294                 16285.500
# 2019-09-08                 11990.252                 15189.125
# 2019-09-15                 11630.000                 20895.125
# 2019-09-22                 11797.286                 22312.375
# 2019-09-29                       NaN                 20928.089
#
# channel     UC--3ozenTzry39-xMqAPQlw  UC--6E6EpybocdaNlPhvK_9A  \
# datetime
# 2017-01-01                 78790.542                 45266.219
# 2017-01-08                 83433.521                 58383.031
# 2017-01-15                176154.271                105656.375
# 2017-01-22                170651.932                118148.547
# 2017-01-29                     0.000                     0.000
# ...                              ...                       ...
# 2019-09-01                 15080.625                 37692.100
# 2019-09-08                 14170.625                 36827.850
# 2019-09-15                 14706.125                 37179.917
# 2019-09-22                 15116.625                 29436.722
# 2019-09-29                 13857.625                 26166.968
#
# channel     UC--70ql_IxJmhmqXqrkJrWQ  UC--BMyA2X4a9PGAo3lTuopg  \
# datetime
# 2017-01-01                 58624.651                230144.542
# 2017-01-08                261201.391                211393.042
# 2017-01-15                436874.953                410550.208
# 2017-01-22                237834.172                351185.609
# 2017-01-29                     0.000                     0.000
# ...                              ...                       ...
# 2019-09-01                114632.875                237070.750
# 2019-09-08                104873.125                227507.750
# 2019-09-15                116137.875                228404.750
# 2019-09-22                130651.875                228743.375
# 2019-09-29                117065.964                179765.911
#
# channel     UC--EwQJeJ6SKlJdswehQH4g  UC--LAVm36WiCmqQbekV17qQ  \
# datetime
# 2017-01-01                  3141.141                405090.474
# 2017-01-08                  3132.073                513466.229
# 2017-01-15                  5420.714                804861.375
# 2017-01-22                  4501.188                517145.125
# 2017-01-29                     0.000                     0.000
# ...                              ...                       ...
# 2019-09-01                142106.750                896308.000
# 2019-09-08                174397.875                721268.625
# 2019-09-15                 14665.875                754182.375
# 2019-09-22                  9969.750               1548685.500
# 2019-09-29                 15093.964               1823589.357
#
# channel     UC--MxpGXJ3LVD8KvlNzRlcA  UC--SaadDxRXz729rtbQqyBA  ...  \
# datetime                                                        ...
# 2017-01-01                152664.714                218213.260  ...
# 2017-01-08                128403.047                166920.260  ...
# 2017-01-15                267081.979                180527.938  ...
# 2017-01-22                268256.380                173103.469  ...
# 2017-01-29                     0.000                     0.000  ...
# ...                              ...                       ...  ...
# 2019-09-01                741449.000                  6857.195  ...
# 2019-09-08                734633.375                  6700.474  ...
# 2019-09-15                723529.625                  6700.474  ...
# 2019-09-22                650013.875                  8029.700  ...
# 2019-09-29                475695.982                  8686.443  ...
#
# channel     UCzzfu83LhPMMuhtDVA75rfw  UCzzgEOi0xR9SuflkXmTQv6g  \
# datetime
# 2017-01-01                107774.234                 50608.250
# 2017-01-08                165696.859                 66100.979
# 2017-01-15                303092.307                269860.010
# 2017-01-22                 50091.531                135643.083
# 2017-01-29                     0.000                108857.875
# ...                              ...                       ...
# 2019-09-01                290734.818                 14579.444
# 2019-09-08                161183.750                 12273.333
# 2019-09-15                305132.750                 10735.667
# 2019-09-22                259474.250                 17552.333
# 2019-09-29                176234.107                 14244.714
#
# channel     UCzzmGsmy8cBxmqljbVG_e7Q  UCzzoJY_ln_StRVdrRX1_ftg  \
# datetime
# 2017-01-01                  1723.201                  4365.896
# 2017-01-08                  2196.625                  2537.089
# 2017-01-15                  4063.500                 11802.484
# 2017-01-22                  1467.172                 18982.250
# 2017-01-29                     0.000                     0.000
# ...                              ...                       ...
# 2019-09-01                 41196.345                142957.769
# 2019-09-08                 30090.455                128864.538
# 2019-09-15                 52301.900                118294.615
# 2019-09-22                 44120.600                122725.962
# 2019-09-29                 40772.214                133880.500
#
# channel     UCzzqd0yx7h1PuC3KJVqeJgw  UCzzsKg4jPGBL05t2w3HfHBA  \
# datetime
# 2017-01-01                   389.792                 17874.796
# 2017-01-08                   413.875                 21798.781
# 2017-01-15                  1117.375                 44051.906
# 2017-01-22                     0.000                 40054.531
# 2017-01-29                    97.125                     0.000
# ...                              ...                       ...
# 2019-09-01                  7220.889                  9817.895
# 2019-09-08                  7211.586                  8243.053
# 2019-09-15                  5658.000                  8243.053
# 2019-09-22                  5663.429                 54022.500
# 2019-09-29                       NaN                 42393.643
#
# channel     UCzzt-UNlRHbEFY3rEpFpuXw  UCzzzPMh9fZHxc7gxPRB2LHQ  \
# datetime
# 2017-01-01                 14840.513                 11938.087
# 2017-01-08                 15995.781                 16928.234
# 2017-01-15                 24833.911                 23935.083
# 2017-01-22                 20701.083                 28294.255
# 2017-01-29                     0.000                     0.000
# ...                              ...                       ...
# 2019-09-01                  7240.125                121074.100
# 2019-09-08                  6965.250                 37997.750
# 2019-09-15                  7610.750                 73245.850
# 2019-09-22                  8852.000                161366.100
# 2019-09-29                       NaN                 74384.871
#
# channel     UCzzzUN8yvD2LRAnY-lhzyLQ  UCzzzZ3-icktxbC3j7hkWqRw
# datetime
# 2017-01-01                  8823.580                 57680.059
# 2017-01-08                 11129.797                 68525.880
# 2017-01-15                 17847.375                141159.036
# 2017-01-22                  8019.599                 89166.245
# 2017-01-29                  1184.635                     0.000
# ...                              ...                       ...
# 2019-09-01               1959046.500                 97305.600
# 2019-09-08               1927067.333                 77068.255
# 2019-09-15               1939274.833                 71936.345
# 2019-09-22               1944157.833                 67538.800
# 2019-09-29                       NaN                 67823.543
#
# [144 rows x 88732 columns]

# %%
num_start_timestamp = 30
X = channel_timeseries[:num_start_timestamp]
y = channel_timeseries[num_start_timestamp:]

# %%
test_size = int(0.2 * len(X.columns))
X_train = X.iloc[:,test_size:]
X_test = X.iloc[:, :test_size]
y_train = y.iloc[:, test_size:]
y_test = y.iloc[:, :test_size]
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

# %%
xg_reg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# /Users/antoinedaeniker/Documents/EPFL/1_Master 3/ADA/ada-2022-project-pinacolada/predictions.ipynb Cellule 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/antoinedaeniker/Documents/EPFL/1_Master%203/ADA/ada-2022-project-pinacolada/predictions.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> xg_reg.fit(X_train, y_train)
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1014, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1012 with config_context(verbosity=self.verbosity):
#    1013     evals_result: TrainingCallback.EvalsLog = {}
# -> 1014     train_dmatrix, evals = _wrap_evaluation_matrices(
#    1015         missing=self.missing,
#    1016         X=X,
#    1017         y=y,
#    1018         group=None,
#    1019         qid=None,
#    1020         sample_weight=sample_weight,
#    1021         base_margin=base_margin,
#    1022         feature_weights=feature_weights,
#    1023         eval_set=eval_set,
#    1024         sample_weight_eval_set=sample_weight_eval_set,
#    1025         base_margin_eval_set=base_margin_eval_set,
#    1026         eval_group=None,
#    1027         eval_qid=None,
#    1028         create_dmatrix=self._create_dmatrix,
#    1029         enable_categorical=self.enable_categorical,
#    1030         feature_types=self.feature_types,
#    1031     )
#    1032     params = self.get_xgb_params()
#    1034     if callable(self.objective):
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:448, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     428 def _wrap_evaluation_matrices(
#     429     missing: float,
#     430     X: Any,
#    (...)
#     444     feature_types: Optional[FeatureTypes],
#     445 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     446     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     447     way."""
# --> 448     train_dmatrix = create_dmatrix(
#     449         data=X,
#     450         label=y,
#     451         group=group,
#     452         qid=qid,
#     453         weight=sample_weight,
#     454         base_margin=base_margin,
#     455         feature_weights=feature_weights,
#     456         missing=missing,
#     457         enable_categorical=enable_categorical,
#     458         feature_types=feature_types,
#     459         ref=None,
#     460     )
#     462     n_validation = 0 if eval_set is None else len(eval_set)
#     464     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:934, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     932     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     933         pass
# --> 934 return DMatrix(**kwargs, nthread=self.n_jobs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:754, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     751 assert handle is not None
#     752 self.handle = handle
# --> 754 self.set_info(
#     755     label=label,
#     756     weight=weight,
#     757     base_margin=base_margin,
#     758     group=group,
#     759     qid=qid,
#     760     label_lower_bound=label_lower_bound,
#     761     label_upper_bound=label_upper_bound,
#     762     feature_weights=feature_weights,
#     763 )
#     765 if feature_names is not None:
#     766     self.feature_names = feature_names
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:819, in DMatrix.set_info(self, label, weight, base_margin, group, qid, label_lower_bound, label_upper_bound, feature_names, feature_types, feature_weights)
#     816 from .data import dispatch_meta_backend
#     818 if label is not None:
# --> 819     self.set_label(label)
#     820 if weight is not None:
#     821     self.set_weight(weight)
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:950, in DMatrix.set_label(self, label)
#     942 """Set label of dmatrix
#     943
#     944 Parameters
#    (...)
#     947     The label information to be set into DMatrix
#     948 """
#     949 from .data import dispatch_meta_backend
# --> 950 dispatch_meta_backend(self, label, 'label', 'float')
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:1118, in dispatch_meta_backend(matrix, data, name, dtype)
#    1116 if _is_pandas_df(data):
#    1117     data, _, _ = _transform_pandas_df(data, False, meta=name, meta_type=dtype)
# -> 1118     _meta_from_numpy(data, name, dtype, handle)
#    1119     return
#    1120 if _is_pandas_series(data):
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:1037, in _meta_from_numpy(data, field, dtype, handle)
#    1035     raise ValueError("Masked array is not supported.")
#    1036 interface_str = _array_interface(data)
# -> 1037 _check_call(_LIB.XGDMatrixSetInfoFromInterface(handle, c_str(field), interface_str))
#
# File /opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:279, in _check_call(ret)
#     268 """Check the return value of C API call
#     269
#     270 This function will raise exception when error occurs.
#    (...)
#     276     return value from API calls
#     277 """
#     278 if ret != 0:
# --> 279     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [17:46:16] /Users/runner/miniforge3/conda-bld/xgboost-split_1667849653518/work/src/data/data.cc:455: Check failed: this->labels.Size() % this->num_row_ == 0 (24 vs. 0) : Incorrect size for labels.
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x0000000143c35fc4 dmlc::LogMessageFatal::~LogMessageFatal() + 116
#   [bt] (1) 2   libxgboost.dylib                    0x0000000143cd33dd xgboost::MetaInfo::SetInfoFromHost(xgboost::GenericParameter const&, xgboost::StringView, xgboost::Json) + 4301
#   [bt] (2) 3   libxgboost.dylib                    0x0000000143cd21df xgboost::MetaInfo::SetInfo(xgboost::GenericParameter const&, xgboost::StringView, xgboost::StringView) + 159
#   [bt] (3) 4   libxgboost.dylib                    0x0000000143c4d2c9 XGDMatrixSetInfoFromInterface + 249
#   [bt] (4) 5   libffi.7.dylib                      0x000000010d803ead ffi_call_unix64 + 85
#   [bt] (5) 6   ???                                 0x000000030a3a0040 0x0 + 13056475200
